# %%
import pandas as pd
import numpy as np
import scipy

from tqdm.notebook import tqdm

link_results = "원본/results.csv"
link_fifa_rank = "원본/fifa_ranking.csv"

# %%
abbreviations = {'Argentina': 'ARG', 'Australia': 'AUS', 'Belgium': 'BEL', 'Brazil': 'BRA',
                 'Cameroon': 'CMR', 'Canada': 'CAN', 'Colombia': 'COL', 'Costa Rica': 'CRC', 'Croatia': 'CRO',
                 'Denmark': 'DEN', 'Egypt': 'EGY', 'Ecuador': 'ECU', 'England': 'ENG', 'France': 'FRA',
                 'Germany': 'GER','Ghana': 'GHA', 'Iceland': 'ISL', 'Iran': 'IRN','Japan': 'JPN', 'South Korea': 'KOR',
                 'Mexico': 'MEX', 'Morocco': 'MAR', 'Netherlands': 'NED', 'Nigeria': 'NGA', 'Panama': 'PAN','Peru': 'PER', 'Poland': 'POL', 'Portugal': 'POR',
                 'Qatar': 'QAT', 'Saudi Arabia': 'KSA', 'Russia': 'RUS','Senegal': 'SEN', 'Serbia': 'SRB', 'Spain': 'ESP',
                 'Sweden': 'SWE', 'Switzerland': 'SUI','Tunisia': 'TUN', 'United States': 'USA','Uruguay': 'URU', 'Wales': 'WAL'}

# %%
def select_cycle(df, key):
    df = df[(df[key] >= "2002-8-1")].reset_index(drop=True)
    return df

# %%
def plot_knockout_stats(knockout_stats, world_cup):
    df = pd.DataFrame(knockout_stats, columns=['16강', '8강', '4강', '결승', '우승'])
    flag_links = []
    for team in world_cup['teams']:
        flag_links.append('<img src="'+ f'https://cloudinary.fifa.com/api/v3/picture/flags-sq-4/{abbreviations[team]}' + '", width="20px", height="20px" > ')
    df.insert(0, '', flag_links)
    df.insert(1, 'Team', world_cup['teams'])
    df = df.sort_values(
        ['우승','결승', '4강', '8강', '16강'], ascending = [False, False, False, False, False])
    # df['Team'] = all_teams
    df = df.reset_index(drop=True)
    df.index += 1 
    df_style = df.style.background_gradient(cmap='YlOrRd', vmin=0, vmax=100, subset=['16강', '8강', '4강', '결승', '우승'])
    df_style = df_style.format((
        {'16강':lambda x:  "{:2.2f}%".format(x) if x>0 else '< 1%',
         '8강':lambda x:  "{:2.2f}%".format(x) if x>0 else '< 1%',
         '4강':lambda x:  "{:2.2f}%".format(x) if x>0 else '< 1%',
         '결승':lambda x:  "{:2.2f}%".format(x) if x>0 else '< 1%',
         '우승':lambda x:  "{:2.2f}%".format(x) if x>0 else '< 1%',
         }))
    df_style = df_style.set_properties(**{'text-align': 'center'})
    df_style = df_style.set_properties(**{'text-align': 'left'}, subset=['Team'])
    df_style = df_style.set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
    return df_style

# %%
from collections.abc import Iterable

def get_world_cup():
    world_cup = {}
    dfs = pd.read_html(r"https://en.wikipedia.org/wiki/2022_FIFA_World_Cup#Teams")
    world_cup['rank_date'] ='2022-10-06'
    
    for i in range(len(dfs)):
        df = dfs[i]
        cols = list(df.columns.values)

        if isinstance(cols[0], Iterable):
            if any("Tie-breaking criteria" in c for c in cols):
                start = i+1
        
    groups_names = ["A", "B", "C", "D", "E", "F", "G", "H"]
    groups = {"A":[], "B":[], "C":[], "D":[], "E":[], "F":[], "G":[], "H":[]}
    gx = 0
    matches = []
    for i in range(start,start+7*8):
        if (i-start)%7 == 0:
            groups[groups_names[gx]] = list(np.unique(dfs[i].iloc[:,1]))
            gx += 1

        else:
            team1 = dfs[i].columns[0]
            result = dfs[i].columns[1].split('–')
            team2 = dfs[i].columns[2]
            if len(result)>1:
                goals_team1 = int(result[0])
                goals_team2 = int(result[1])
            else:
                goals_team1 = np.nan
                goals_team2 = np.nan
            matches.append((team1, team2, groups_names[gx-1], goals_team1, goals_team2))

    teams_world_cup = []
    for letter in groups:
        teams_group = []
        for team in groups[letter]:
            team = team.replace(' (H)', '')
            teams_group.append(team)
            teams_world_cup.append(team)
        groups[letter] = teams_group

    world_cup['teams'] = teams_world_cup
    world_cup['groups'] = groups
    world_cup['games'] = pd.DataFrame(matches, columns=['Team1', 'Team2', 'Group', 'GT1', 'GT2'])
    return world_cup

# %%
class BaseForecaster():
    def __init__(self):
        pass
    
    def predict_game(self, team1, team2, n_sim):
        raise NotImplementedError

    def print_game_stats(self, team1, team2, n_sim):
        gt1, gt2 = self.predict_game(team1, team2, n_sim)
        # Computing match-win percentages
        outcomes = np.where(gt1>gt2, 'W', np.where(gt2>gt1, 'L', 'D'))
        outcomes, counts = np.unique(outcomes, return_counts=True)
        pct_win_team1 = (counts[outcomes=='W']/sum(counts))[0]*100
        pct_win_team2 = (counts[outcomes=='L']/sum(counts))[0]*100
        pct_draw = (counts[outcomes=='D']/sum(counts))[0]*100
        print(f"Win {abbreviations[team1]}: {pct_win_team1:.2f}%")
        print(f"Win {abbreviations[team2]}: {pct_win_team2:.2f}%")
        print(f"Draw: {pct_draw:.2f}%")

        # Computing most likely score
        values, counts = np.unique(np.vstack([gt1,gt2]), return_counts=True, axis=1)
        goals_team1, goals_team2 = values[:, counts==max(counts)]
        print(f'Most likely final score: {abbreviations[team1]} {goals_team1[0]} - {goals_team2[0]} {abbreviations[team2]}')

    def predict_group_stage(self, world_cup, n_sim):        
        gt1 = np.zeros((len(world_cup['games']), n_sim))
        gt2 = np.zeros((len(world_cup['games']), n_sim))
        for i in range(len(world_cup['games'])):
            team1 = world_cup['games'].iloc[i]['Team1']
            team2 = world_cup['games'].iloc[i]['Team2']
            gt1[i,:], gt2[i,:] = self.predict_game(team1, team2, n_sim)

        pt1 = np.where(gt1>gt2, 3, np.where(gt1<gt2, 0, 1))
        pt2 = np.where(gt1>gt2, 0, np.where(gt1<gt2, 3, 1))
        return pt1, pt2
    
    def points_score_predictions_group_stage(self, world_cup, n_sim):
        gt1 = np.zeros((len(world_cup['games']), n_sim))
        gt2 = np.zeros((len(world_cup['games']), n_sim))
        for i in range(len(world_cup['games'])):
            team1 = world_cup['games'].iloc[i]['Team1']
            team2 = world_cup['games'].iloc[i]['Team2']
            gt1[i,:], gt2[i,:] = self.predict_game(team1, team2, n_sim)

        predicted_gt1 = np.zeros(len(world_cup['games']))
        predicted_gt2 = np.zeros(len(world_cup['games']))
        for i in range(len(world_cup['games'])):
            values, counts = np.unique(np.vstack([gt1[i,:], gt2[i,:]]), return_counts=True, axis=1)
            result = values[:,counts==max(counts)].flatten()
            predicted_gt1[i] = result[0]
            predicted_gt2[i] = result[1]
        true_outcome = np.where(world_cup['games']['GT1']>world_cup['games']['GT2'], 
                 'H', np.where(world_cup['games']['GT1']<world_cup['games']['GT2'], 'A','D'))
        predicted_outcome = np.where(predicted_gt1>predicted_gt2,'H', np.where(predicted_gt2>predicted_gt1, 'A','D'))
        correct_outcome = true_outcome == predicted_outcome
        correct_t1 = world_cup['games']['GT1'] == predicted_gt1
        correct_t2 = world_cup['games']['GT2'] == predicted_gt2
        correct_difference = (world_cup['games']['GT1']-world_cup['games']['GT2']) == predicted_gt1-predicted_gt2
        correct_score = np.logical_and(world_cup['games']['GT1'] == predicted_gt1, world_cup['games']['GT2'] == predicted_gt2)
        points = 3*sum(correct_outcome)+1*sum(correct_t1)+1*sum(correct_t2)+1*sum(correct_difference)+2*sum(correct_score)
        return points

    def get_group_stage_stats(self, pt1, pt2, world_cup):
        n_sim = pt1.shape[1]
        points_per_simulation = {}
        for team in world_cup['teams']:
            points_per_simulation[team] = pt1[world_cup['games']['Team1']==team,:].sum(axis=0)+pt2[world_cup['games']['Team2']==team,:].sum(axis=0)
        probs = {}
        prediction = {}
        positions = {}
        for letter in world_cup['groups']:
            teams = np.array(world_cup['groups'][letter])
            points_per_team = []
            for team in teams:
                points_per_team.append(points_per_simulation[team])
            positions[letter] = 5-scipy.stats.rankdata(points_per_team, axis=0, method='ordinal')
            probs[letter] = {}
            for i, team in enumerate(teams):
                probs[letter][team] = {}
                for pos in range(1,5):
                    probs[letter][team][pos] = sum(positions[letter][i,:]==pos)/n_sim*100
            values, counts = np.unique(positions[letter], return_counts=True, axis=1)
            prediction[letter] = list(values[:,counts==max(counts)].flatten())
        return probs, positions, prediction
    
    def predict_knockouts(self, positions, world_cup):   
        knockout_stages = ['16강', '8강', '4강', '결승', '우승']
        pairing = [0,3,4,7,8,11,12,15,1,2,5,6,9,10,13,14]
        n_teams = 16
        n_sim = positions['A'].shape[1]
        knockouts = {}
        for stage_ix, stage in enumerate(knockout_stages):
            if stage == '16강':
                knockouts[stage] = np.zeros((16, n_sim))
                ix = 0
                for letter in world_cup['groups']:
                    teams = np.array(world_cup['groups'][letter])
                    for i in range(4):
                        knockouts[stage][pairing[ix], positions[letter][i,:] == 1] = np.arange(32)[np.array(world_cup['teams'])==teams[i]]
                        knockouts[stage][pairing[ix+1], positions[letter][i,:] == 2] = np.arange(32)[np.array(world_cup['teams'])==teams[i]]
                    ix += 2
            else:
                prev_stage = knockout_stages[stage_ix-1]
                n_games = knockouts[prev_stage].shape[0]//2
                knockouts[stage] = np.zeros((n_games, n_sim))
                for i in range(n_games):
                    for sim in range(n_sim):
                        team1 = world_cup['teams'][int(knockouts[prev_stage][2*i,sim])]
                        team2 = world_cup['teams'][int(knockouts[prev_stage][2*i+1,sim])]
                        gt1, gt2 = self.predict_game(team1, team2, 1)
                        while gt1 == gt2:
                            gt1, gt2 = self.predict_game(team1, team2, 1)
                        if gt1>gt2:
                            knockouts[stage][i, sim] = np.arange(32)[np.array(world_cup['teams'])==team1]
                        elif gt2>gt1:
                            knockouts[stage][i, sim] = np.arange(32)[np.array(world_cup['teams'])==team2]
        return knockouts
    
    def get_knockouts_stats(self, knockouts, world_cup):
        n_sim = knockouts['우승'].shape[1]
        knockouts_stats = np.zeros((len(world_cup['teams']),5))
        for stage_ix, stage in enumerate(knockouts):
            values, counts = np.unique(knockouts[stage], return_counts=True)
            for values_ix, v in enumerate(values):
                knockouts_stats[int(v),stage_ix] = counts[values_ix]/n_sim*100
        return knockouts_stats

# %%
class PoissonGoals(BaseForecaster):
    def __init__(self, world_cup):
        db_games =  pd.read_csv(link_results)
        db_games["date"] = pd.to_datetime(db_games["date"])
        db_games.dropna(inplace=True)
        db_games = select_cycle(db_games,"date")
        self.db_games = db_games
        data = []
        for team in world_cup['teams']:
            select = np.logical_and(db_games['home_team']==team, np.logical_not(db_games['neutral']))
            n_hg = sum(select)
            gf_hg = sum(db_games[select]['home_score'])
            ga_hg = sum(db_games[select]['away_score'])
            select = np.logical_and(db_games['away_team']==team, np.logical_not(db_games['neutral']))
            n_ag = sum(select)
            gf_ag = sum(db_games[select]['away_score'])
            ga_ag = sum(db_games[select]['home_score'])
            select = np.logical_and(db_games['home_team']==team, db_games['neutral'])
            n_ngh = sum(select)
            gf_ngh = sum(db_games[select]['home_score'])
            ga_ngh = sum(db_games[select]['away_score'])
            select = np.logical_and(db_games['away_team']==team, db_games['neutral'])
            n_nga = sum(select)
            gf_nga = sum(db_games[select]['away_score'])
            ga_nga = sum(db_games[select]['home_score'])
            gf_ng = gf_ngh+gf_nga
            ga_ng = ga_ngh+ga_nga
            n_ng = n_ngh+n_nga
            data.append([team, n_hg, gf_hg, ga_hg, n_ag, gf_ag, ga_ag, n_ng, gf_ng, ga_ng])
        df = pd.DataFrame(data, columns=['Team', 'n_hg', 'gf_hg', 'ga_hg', 'n_ag', 'gf_ag', 'ga_ag', 'n_ng', 'gf_ng', 'ga_ng'])
        self.df = df
        has = ((df['gf_hg']+df['gf_ng'])/(df['n_hg']+df['n_ng']))/((sum(df['gf_hg'])+sum(df['gf_ng']))/(sum(df['n_hg'])+sum(df['n_ng'])))
        hds = ((df['ga_hg']+df['ga_ng'])/(df['n_hg']+df['n_ng']))/((sum(df['ga_hg'])+sum(df['ga_ng']))/(sum(df['n_hg'])+sum(df['n_ng'])))
        aas = ((df['gf_ag']+df['gf_ng'])/(df['n_hg']+df['n_ng']))/((sum(df['gf_ag'])+sum(df['gf_ng']))/(sum(df['n_hg'])+sum(df['n_ng'])))
        ads = ((df['ga_ag']+df['ga_ng'])/(df['n_hg']+df['n_ng']))/((sum(df['ga_ag'])+sum(df['ga_ng']))/(sum(df['n_hg'])+sum(df['n_ng'])))
        self.strengths = {}
        for i, team in enumerate(world_cup['teams']):
            self.strengths[team] = {}
            self.strengths[team]['has'] = has[i]
            self.strengths[team]['hds'] = hds[i]
            self.strengths[team]['aas'] = aas[i]
            self.strengths[team]['ads'] = ads[i]
    
    def predict_game(self, team1, team2, n_sim):
        if (team1 == 'Qatar'):
            gt1 = np.random.poisson(lam=self.strengths[team1]['has']*self.strengths[team2]['ads'], size=n_sim)
            gt2 = np.random.poisson(lam=self.strengths[team2]['aas']*self.strengths[team1]['hds'], size=n_sim)
        elif (team2 == 'Qatar'):
            gt1 = np.random.poisson(lam=self.strengths[team1]['aas']*self.strengths[team2]['hds'], size=n_sim)
            gt2 = np.random.poisson(lam=self.strengths[team2]['has']*self.strengths[team1]['ads'], size=n_sim)
        else:
            gt1 = np.random.poisson(lam=(self.strengths[team1]['has']*self.strengths[team2]['ads']+self.strengths[team1]['aas']*self.strengths[team2]['hds'])/2, size=n_sim)
            gt2 = np.random.poisson(lam=(self.strengths[team2]['aas']*self.strengths[team1]['hds']+self.strengths[team2]['has']*self.strengths[team1]['ads'])/2, size=n_sim)
        return gt1, gt2

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import PoissonRegressor
class PoissonFifaRank(BaseForecaster):
    def __init__(self, world_cup):
        db_games =  pd.read_csv(link_results)
        db_games["date"] = pd.to_datetime(db_games["date"])
        db_games.dropna(inplace=True)
        db_games = select_cycle(db_games,"date")
        db_games = db_games[['date', 'home_team', 'away_team', 'home_score', 'away_score', 'tournament', 'neutral']]
        rank = pd.read_csv(link_fifa_rank)
        rank["rank_date"] = pd.to_datetime(rank["rank_date"])
        rank = select_cycle(rank, key='rank_date')
        rank["country_full"] = rank["country_full"].str.replace("IR Iran", "Iran").str.replace("Korea Republic", "South Korea").str.replace("USA", "United States")
        rank = rank.set_index(['rank_date']).groupby(['country_full'], group_keys=False).resample('D').first().fillna(method='ffill').reset_index()
        df_wc_ranked = db_games.merge(rank[["country_full", "total_points", "rank_date"]], left_on=["date", "home_team"], right_on=["rank_date", "country_full"]).drop(["rank_date", "country_full"], axis=1)
        df_wc_ranked = df_wc_ranked.merge(rank[["country_full", "total_points", "rank_date"]], left_on=["date", "away_team"], right_on=["rank_date", "country_full"], suffixes=("_home", "_away")).drop(["rank_date", "country_full"], axis=1)
        df_wc_ranked['is_friendly'] = np.where(df_wc_ranked['tournament'] == 'Friendly',1,0)
        df_wc_ranked['diff_rank'] = np.abs(df_wc_ranked['total_points_home']-df_wc_ranked['total_points_away'])
        df_wc_ranked['ratio_rank'] = np.maximum(df_wc_ranked['total_points_home'],df_wc_ranked['total_points_away'])/np.minimum(df_wc_ranked['total_points_home'],df_wc_ranked['total_points_away'])
        df_wc_ranked['best_score'] = np.where(df_wc_ranked['total_points_home']>df_wc_ranked['total_points_away'], df_wc_ranked['home_score'], df_wc_ranked['away_score'])
        df_wc_ranked['worst_score'] = np.where(df_wc_ranked['total_points_home']>df_wc_ranked['total_points_away'], df_wc_ranked['away_score'], df_wc_ranked['home_score'])
        self.poisson_gml_best = make_pipeline(StandardScaler(), PoissonRegressor(alpha=1e-12, max_iter=500))
        self.poisson_gml_best.fit(df_wc_ranked[['diff_rank']].values, df_wc_ranked['best_score'])
        self.poisson_gml_worst = make_pipeline(StandardScaler(), PoissonRegressor(alpha=1e-12, max_iter=500))
        self.poisson_gml_worst.fit(df_wc_ranked[['diff_rank']].values, df_wc_ranked['worst_score'])
        
        
        self.fifa_rank = {}
        for team in world_cup['teams']:
            self.fifa_rank[team] = rank[np.logical_and(rank["rank_date"]== world_cup['rank_date'], rank['country_full'] == team)]['total_points'].values[0]
        
    def predict_game(self, team1, team2, n_sim):
        diff = np.abs(self.fifa_rank[team1]-self.fifa_rank[team2])
        if self.fifa_rank[team1]>self.fifa_rank[team2]:   
            gt1 = np.random.poisson(lam=self.poisson_gml_best.predict([[diff]]), size=n_sim)
            gt2 = np.random.poisson(lam=self.poisson_gml_worst.predict([[diff]]), size=n_sim)
        else:
            gt1 = np.random.poisson(lam=self.poisson_gml_worst.predict([[diff]]), size=n_sim)
            gt2 = np.random.poisson(lam=self.poisson_gml_best.predict([[diff]]), size=n_sim)
        return gt1, gt2

# %%
world_cup = get_world_cup()

# %%
scores = []
for n in range(10):
    scores.append(PoissonGoals(world_cup).points_score_predictions_group_stage(world_cup, 1000))
print('Poisson Goal Based')
print(f'Avg Score: {np.mean(scores):.2f}\u00B1{np.std(scores):.2f}')
print(f'Max Score: {np.max(scores)}')
print(f'Min Score: {np.min(scores)}')
# Out:
# Poisson Goal Based
# Avg Score: 117.20±11.32
# Max Score: 135
# Min Score: 97

# %%
scores = []
for n in range(10):
    scores.append(PoissonFifaRank(world_cup).points_score_predictions_group_stage(world_cup, 1000))
print('Poisson Rank Based')
print(f'Avg Score: {np.mean(scores):.2f}\u00B1{np.std(scores):.2f}')
print(f'Max Score: {np.max(scores)}')
print(f'Min Score: {np.min(scores)}')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Poisson Rank Based
# Avg Score: 116.50±8.51
# Max Score: 125
# Min Score: 100

# %%
n_sim = 1000
model_goals = PoissonGoals(world_cup)
pt1, pt2 = model_goals.predict_group_stage(world_cup, n_sim)
probs, positions, prediction = model_goals.get_group_stage_stats(pt1, pt2, world_cup)
knockouts = model_goals.predict_knockouts(positions, world_cup)
knockout_stats = model_goals.get_knockouts_stats(knockouts, world_cup)
plot_knockout_stats(knockout_stats, world_cup)
# Out:
# <style type="text/css">
# #T_1cbc5 th {
#   text-align: center;
# }
# #T_1cbc5_row0_col0, #T_1cbc5_row1_col0, #T_1cbc5_row2_col0, #T_1cbc5_row3_col0, #T_1cbc5_row4_col0, #T_1cbc5_row5_col0, #T_1cbc5_row6_col0, #T_1cbc5_row7_col0, #T_1cbc5_row8_col0, #T_1cbc5_row9_col0, #T_1cbc5_row10_col0, #T_1cbc5_row11_col0, #T_1cbc5_row12_col0, #T_1cbc5_row13_col0, #T_1cbc5_row14_col0, #T_1cbc5_row15_col0, #T_1cbc5_row16_col0, #T_1cbc5_row17_col0, #T_1cbc5_row18_col0, #T_1cbc5_row19_col0, #T_1cbc5_row20_col0, #T_1cbc5_row21_col0, #T_1cbc5_row22_col0, #T_1cbc5_row23_col0, #T_1cbc5_row24_col0, #T_1cbc5_row25_col0, #T_1cbc5_row26_col0, #T_1cbc5_row27_col0, #T_1cbc5_row28_col0, #T_1cbc5_row29_col0, #T_1cbc5_row30_col0, #T_1cbc5_row31_col0 {
#   text-align: center;
# }
# #T_1cbc5_row0_col1, #T_1cbc5_row1_col1, #T_1cbc5_row2_col1, #T_1cbc5_row3_col1, #T_1cbc5_row4_col1, #T_1cbc5_row5_col1, #T_1cbc5_row6_col1, #T_1cbc5_row7_col1, #T_1cbc5_row8_col1, #T_1cbc5_row9_col1, #T_1cbc5_row10_col1, #T_1cbc5_row11_col1, #T_1cbc5_row12_col1, #T_1cbc5_row13_col1, #T_1cbc5_row14_col1, #T_1cbc5_row15_col1, #T_1cbc5_row16_col1, #T_1cbc5_row17_col1, #T_1cbc5_row18_col1, #T_1cbc5_row19_col1, #T_1cbc5_row20_col1, #T_1cbc5_row21_col1, #T_1cbc5_row22_col1, #T_1cbc5_row23_col1, #T_1cbc5_row24_col1, #T_1cbc5_row25_col1, #T_1cbc5_row26_col1, #T_1cbc5_row27_col1, #T_1cbc5_row28_col1, #T_1cbc5_row29_col1, #T_1cbc5_row30_col1, #T_1cbc5_row31_col1 {
#   text-align: center;
#   text-align: left;
# }
# #T_1cbc5_row0_col2 {
#   background-color: #c70723;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cbc5_row0_col3, #T_1cbc5_row7_col2 {
#   background-color: #fc5d2e;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cbc5_row0_col4 {
#   background-color: #feaf4b;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row0_col5 {
#   background-color: #fed673;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row0_col6 {
#   background-color: #ffe48c;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row1_col2 {
#   background-color: #da141e;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cbc5_row1_col3 {
#   background-color: #fc6a32;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cbc5_row1_col4 {
#   background-color: #fea546;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row1_col5 {
#   background-color: #fecb67;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row1_col6 {
#   background-color: #ffe58f;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row2_col2 {
#   background-color: #ea2920;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cbc5_row2_col3 {
#   background-color: #febd57;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row2_col4, #T_1cbc5_row17_col3 {
#   background-color: #fee187;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row2_col5 {
#   background-color: #ffeda1;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row2_col6, #T_1cbc5_row24_col4 {
#   background-color: #fff6b6;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row3_col2 {
#   background-color: #f43e26;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cbc5_row3_col3, #T_1cbc5_row4_col3 {
#   background-color: #feae4a;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row3_col4 {
#   background-color: #fedb7b;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row3_col5, #T_1cbc5_row4_col5 {
#   background-color: #ffeea3;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row3_col6, #T_1cbc5_row4_col6, #T_1cbc5_row18_col4, #T_1cbc5_row26_col4 {
#   background-color: #fff7b7;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row4_col2 {
#   background-color: #f84628;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cbc5_row4_col4, #T_1cbc5_row14_col3, #T_1cbc5_row15_col3 {
#   background-color: #fedb7a;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row5_col2, #T_1cbc5_row10_col2 {
#   background-color: #fc512b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cbc5_row5_col3 {
#   background-color: #feb04b;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row5_col4, #T_1cbc5_row12_col3, #T_1cbc5_row20_col3 {
#   background-color: #fedd7f;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row5_col5, #T_1cbc5_row12_col4, #T_1cbc5_row13_col4, #T_1cbc5_row14_col4 {
#   background-color: #fff1ab;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row5_col6, #T_1cbc5_row6_col6, #T_1cbc5_row22_col4 {
#   background-color: #fff8ba;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row6_col2 {
#   background-color: #fc5f2f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cbc5_row6_col3 {
#   background-color: #fec561;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row6_col4 {
#   background-color: #ffe691;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row6_col5, #T_1cbc5_row7_col5 {
#   background-color: #fff0a7;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row7_col3, #T_1cbc5_row24_col2 {
#   background-color: #feb54f;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row7_col4, #T_1cbc5_row11_col3, #T_1cbc5_row19_col3 {
#   background-color: #fedf83;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row7_col6, #T_1cbc5_row29_col3 {
#   background-color: #fff8bb;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row8_col2 {
#   background-color: #f74327;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cbc5_row8_col3 {
#   background-color: #febf5a;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row8_col4, #T_1cbc5_row16_col3 {
#   background-color: #fee289;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row8_col5, #T_1cbc5_row16_col4, #T_1cbc5_row21_col4 {
#   background-color: #fff2ac;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row8_col6, #T_1cbc5_row9_col6, #T_1cbc5_row11_col5, #T_1cbc5_row12_col5 {
#   background-color: #fff9be;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row9_col2 {
#   background-color: #fd7034;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cbc5_row9_col3 {
#   background-color: #feb953;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row9_col4 {
#   background-color: #ffe590;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row9_col5, #T_1cbc5_row23_col4 {
#   background-color: #fff3ae;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row10_col3 {
#   background-color: #fed774;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row10_col4 {
#   background-color: #fff1a9;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row10_col5, #T_1cbc5_row13_col5, #T_1cbc5_row25_col4, #T_1cbc5_row28_col4 {
#   background-color: #fff9bd;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row10_col6, #T_1cbc5_row11_col6, #T_1cbc5_row23_col5, #T_1cbc5_row24_col5, #T_1cbc5_row28_col5 {
#   background-color: #fffcc5;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row11_col2 {
#   background-color: #fd923e;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row11_col4 {
#   background-color: #fff3af;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row12_col2 {
#   background-color: #fd8c3c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cbc5_row12_col6, #T_1cbc5_row13_col6, #T_1cbc5_row22_col5, #T_1cbc5_row25_col5, #T_1cbc5_row26_col5, #T_1cbc5_row30_col4 {
#   background-color: #fffdc6;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row13_col2, #T_1cbc5_row19_col2 {
#   background-color: #fd9d43;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row13_col3, #T_1cbc5_row23_col3 {
#   background-color: #fede80;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row14_col2 {
#   background-color: #fd883b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cbc5_row14_col5, #T_1cbc5_row17_col5, #T_1cbc5_row31_col3 {
#   background-color: #fffac1;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row14_col6, #T_1cbc5_row15_col6, #T_1cbc5_row16_col6 {
#   background-color: #fffdc8;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row15_col2 {
#   background-color: #fd8f3d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cbc5_row15_col4, #T_1cbc5_row19_col4 {
#   background-color: #fff0a8;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row15_col5, #T_1cbc5_row16_col5, #T_1cbc5_row19_col5 {
#   background-color: #fffac0;
#   color: #000000;
#   text-align: center;
# }
# #T_1cbc5_row16_col2 {
#   background-c

# %%
n_sim = 1000
model_fifa_rank = PoissonFifaRank(world_cup)
pt1, pt2 = model_fifa_rank.predict_group_stage(world_cup, n_sim)
probs, positions, prediction = model_fifa_rank.get_group_stage_stats(pt1, pt2, world_cup)
knockouts = model_fifa_rank.predict_knockouts(positions, world_cup)
knockout_stats = model_fifa_rank.get_knockouts_stats(knockouts, world_cup)
plot_knockout_stats(knockout_stats, world_cup)
# Out:
# <style type="text/css">
# #T_eb2af th {
#   text-align: center;
# }
# #T_eb2af_row0_col0, #T_eb2af_row1_col0, #T_eb2af_row2_col0, #T_eb2af_row3_col0, #T_eb2af_row4_col0, #T_eb2af_row5_col0, #T_eb2af_row6_col0, #T_eb2af_row7_col0, #T_eb2af_row8_col0, #T_eb2af_row9_col0, #T_eb2af_row10_col0, #T_eb2af_row11_col0, #T_eb2af_row12_col0, #T_eb2af_row13_col0, #T_eb2af_row14_col0, #T_eb2af_row15_col0, #T_eb2af_row16_col0, #T_eb2af_row17_col0, #T_eb2af_row18_col0, #T_eb2af_row19_col0, #T_eb2af_row20_col0, #T_eb2af_row21_col0, #T_eb2af_row22_col0, #T_eb2af_row23_col0, #T_eb2af_row24_col0, #T_eb2af_row25_col0, #T_eb2af_row26_col0, #T_eb2af_row27_col0, #T_eb2af_row28_col0, #T_eb2af_row29_col0, #T_eb2af_row30_col0, #T_eb2af_row31_col0 {
#   text-align: center;
# }
# #T_eb2af_row0_col1, #T_eb2af_row1_col1, #T_eb2af_row2_col1, #T_eb2af_row3_col1, #T_eb2af_row4_col1, #T_eb2af_row5_col1, #T_eb2af_row6_col1, #T_eb2af_row7_col1, #T_eb2af_row8_col1, #T_eb2af_row9_col1, #T_eb2af_row10_col1, #T_eb2af_row11_col1, #T_eb2af_row12_col1, #T_eb2af_row13_col1, #T_eb2af_row14_col1, #T_eb2af_row15_col1, #T_eb2af_row16_col1, #T_eb2af_row17_col1, #T_eb2af_row18_col1, #T_eb2af_row19_col1, #T_eb2af_row20_col1, #T_eb2af_row21_col1, #T_eb2af_row22_col1, #T_eb2af_row23_col1, #T_eb2af_row24_col1, #T_eb2af_row25_col1, #T_eb2af_row26_col1, #T_eb2af_row27_col1, #T_eb2af_row28_col1, #T_eb2af_row29_col1, #T_eb2af_row30_col1, #T_eb2af_row31_col1 {
#   text-align: center;
#   text-align: left;
# }
# #T_eb2af_row0_col2 {
#   background-color: #d30f20;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row0_col3, #T_eb2af_row2_col3 {
#   background-color: #fc6430;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row0_col4 {
#   background-color: #fea245;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row0_col5, #T_eb2af_row12_col3 {
#   background-color: #fecb67;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row0_col6 {
#   background-color: #fee084;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row1_col2 {
#   background-color: #e6211e;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row1_col3 {
#   background-color: #fd7c37;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row1_col4, #T_eb2af_row20_col2 {
#   background-color: #feaf4b;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row1_col5, #T_eb2af_row15_col3 {
#   background-color: #fed572;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row1_col6, #T_eb2af_row9_col4 {
#   background-color: #ffe998;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row2_col2 {
#   background-color: #d7121f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row2_col4, #T_eb2af_row18_col2 {
#   background-color: #fea145;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row2_col5 {
#   background-color: #fede82;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row2_col6, #T_eb2af_row10_col4, #T_eb2af_row20_col3 {
#   background-color: #ffec9f;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row3_col2 {
#   background-color: #e0181d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row3_col3 {
#   background-color: #fea546;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row3_col4 {
#   background-color: #fed774;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row3_col5 {
#   background-color: #ffe691;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row3_col6 {
#   background-color: #fff0a8;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row4_col2 {
#   background-color: #f23924;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row4_col3 {
#   background-color: #feac49;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row4_col4 {
#   background-color: #fedd7e;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row4_col5, #T_eb2af_row8_col4 {
#   background-color: #ffe895;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row4_col6, #T_eb2af_row9_col5, #T_eb2af_row23_col3 {
#   background-color: #fff4b2;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row5_col2 {
#   background-color: #ce0c22;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row5_col3 {
#   background-color: #fd7034;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row5_col4 {
#   background-color: #feb54f;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row5_col5 {
#   background-color: #fee38b;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row5_col6, #T_eb2af_row25_col3, #T_eb2af_row26_col3 {
#   background-color: #fff5b5;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row6_col2 {
#   background-color: #db141e;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row6_col3 {
#   background-color: #fd9f44;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row6_col4 {
#   background-color: #fed16e;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row6_col5 {
#   background-color: #ffefa4;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row6_col6, #T_eb2af_row7_col6 {
#   background-color: #fff8bb;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row7_col2 {
#   background-color: #ec2c21;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row7_col3 {
#   background-color: #feb44e;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row7_col4, #T_eb2af_row27_col2 {
#   background-color: #fee085;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row7_col5 {
#   background-color: #fff2ac;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row8_col2 {
#   background-color: #fc4f2a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row8_col3 {
#   background-color: #feb651;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row8_col5 {
#   background-color: #fff5b3;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row8_col6, #T_eb2af_row28_col4 {
#   background-color: #fffbc2;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row9_col2 {
#   background-color: #fc592d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row9_col3 {
#   background-color: #fec05b;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row9_col6, #T_eb2af_row12_col5 {
#   background-color: #fffcc4;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row10_col2, #T_eb2af_row15_col2 {
#   background-color: #fc6631;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row10_col3, #T_eb2af_row28_col2 {
#   background-color: #fec863;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row10_col5, #T_eb2af_row16_col4, #T_eb2af_row17_col4, #T_eb2af_row27_col3, #T_eb2af_row30_col3 {
#   background-color: #fff8ba;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row10_col6, #T_eb2af_row11_col6, #T_eb2af_row16_col5, #T_eb2af_row17_col5, #T_eb2af_row23_col4, #T_eb2af_row25_col4, #T_eb2af_row29_col4 {
#   background-color: #fffdc6;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row11_col2 {
#   background-color: #fc6330;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row11_col3 {
#   background-color: #fece6a;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row11_col4, #T_eb2af_row15_col4 {
#   background-color: #fff1a9;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row11_col5 {
#   background-color: #fff9bd;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row12_col2 {
#   background-color: #f64227;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row12_col4 {
#   background-color: #fff1ab;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row12_col6, #T_eb2af_row13_col6, #T_eb2af_row24_col5, #T_eb2af_row26_col4, #T_eb2af_row27_col4, #T_eb2af_row30_col4 {
#   background-color: #fffdc8;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row13_col2 {
#   background-color: #e9261f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row13_col3 {
#   background-color: #fec561;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row13_col4 {
#   background-color: #ffefa5;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row13_col5, #T_eb2af_row15_col5, #T_eb2af_row18_col4, #T_eb2af_row20_col4, #T_eb2af_row21_col4 {
#   background-color: #fffac1;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_row14_col2 {
#   background-color: #f84528;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_eb2af_row14_col3 {
#   background-color: #fed06c;
#   color: #000000;
#   text-align: center;
# }
# #T_eb2af_

# %%
team1 = 'Spain'
team2 = 'Brazil'
model_goals.print_game_stats(team1, team2, 10000)
# Out:
# Win ESP: 34.06%
# Win BRA: 35.27%
# Draw: 30.67%
# Most likely final score: ESP 1 - 1 BRA

# %%
b = BaseForecaster()
b.print_game_stats('South Korea','Japan',1000)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [85], line 2
#       1 b = BaseForecaster()
# ----> 2 b.print_game_stats('South Korea','Japan',1000)
#
# Cell In [19], line 9, in BaseForecaster.print_game_stats(self, team1, team2, n_sim)
#       8 def print_game_stats(self, team1, team2, n_sim):
# ----> 9     gt1, gt2 = self.predict_game(team1, team2, n_sim)
#      10     # Computing match-win percentages
#      11     outcomes = np.where(gt1>gt2, 'W', np.where(gt2>gt1, 'L', 'D'))
#
# Cell In [19], line 6, in BaseForecaster.predict_game(self, team1, team2, n_sim)
#       5 def predict_game(self, team1, team2, n_sim):
# ----> 6     raise NotImplementedError
#
# NotImplementedError:
